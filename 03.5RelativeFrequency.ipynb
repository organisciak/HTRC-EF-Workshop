# %% [markdown]
# # Relative Frequencies and Stopword lists
#
# - TODO - investigate top words, adapt Eleanor text
#
# Now we'll look at a look using relative frequencies. Relative frequencies are one way at looking at top words, through their proportional counts. Books have different lengths, so the nominal count of any given word will vary between books, so relative frequencies give us a way to compare two or more books.

# %%
# %matplotlib inline
from htrc_features import FeatureReader

# %% [markdown]
# ## Kreacher Example

# %%
vol = FeatureReader(ids=['uc1.32106019703807']).first()
# Out:
#   File "<ipython-input-3-aa48e963cb34>", line 4
#     kreacher.plot(x='page', y='count', kind='dist')?
#                                                    ^
# SyntaxError: invalid syntax

# %%
tl = vol.tokenlist(pos=True, pages=True, case=True)
kreacher = tl.loc[(slice(None), slice(None), 'Kreacher','NNP'),].reset_index()
kreacher.plot(x='page', y='count', kind='hist')

# %%
harry = tl.loc[(slice(None), slice(None), 'Harry','NNP'),].reset_index()
harry.plot(x='page', y='count', kind='hist', ylim=(0, 200))

# %%
hermione = tl.loc[(slice(None), slice(None), 'Hermione','NNP'),].reset_index()
hermione.plot(x='page', y='count', kind='hist', ylim=(0, 200))

# %% [markdown]
# ## Relative Frequencies

# %%
fr = FeatureReader('data/sample-file1.json.bz2')
vol = fr.first()
tokens = vol.tokenlist(pages=False, pos=False, case=False)
tokens = tokens.loc['body'] # Only focus on section='body'

# %%
tokens['rel_freq'] = tokens['count'] / tokens['count'].sum()
tokens = tokens.sort_values('rel_freq', ascending=False)
tokens.head(15).plot(y='rel_freq', kind='bar', title='Common token frequencies in ' + vol.title)

# %%
from nltk.corpus import stopwords
print(stopwords.words('english'))
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
subset = tokens[~tokens.index.isin(stopwords.words('english')) & tokens.index.str.isalpha()]
subset.head(15).plot(y='rel_freq', kind='bar', title='Common token frequencies in ' + vol.title)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-c0aaf71e8977> in <module>()
# ----> 1 subset = tokens[~tokens.index.isin(stopwords.words('english')) & tokens.index.str.isalpha()]
#       2 subset.head(15).plot(y='rel_freq', kind='bar', title='Common token frequencies in ' + vol.title)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/multi.py in isin(self, values, level)
#    2936         if level is None:
#    2937             values = MultiIndex.from_tuples(values,
# -> 2938                                             names=self.names).values
#    2939             return algos.isin(self.values, values)
#    2940         else:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/multi.py in from_tuples(cls, tuples, sortorder, names)
#    1354             arrays = lzip(*tuples)
#    1355
# -> 1356         return MultiIndex.from_arrays(arrays, sortorder=sortorder, names=names)
#    1357
#    1358     @classmethod
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/multi.py in from_arrays(cls, arrays, sortorder, names)
#    1303
#    1304         return MultiIndex(levels=levels, labels=labels, sortorder=sortorder,
# -> 1305                           names=names, verify_integrity=False)
#    1306
#    1307     @classmethod
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/multi.py in __new__(cls, levels, labels, sortorder, names, dtype, copy, name, verify_integrity, _set_identity)
#     230         if names is not None:
#     231             # handles name validation
# --> 232             result._set_names(names)
#     233
#     234         if sortorder is not None:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/multi.py in _set_names(self, names, level, validate)
#     668             raise ValueError('Length of names must match length of level.')
#     669         if validate and level is None and len(names) != self.nlevels:
# --> 670             raise ValueError('Length of names must match number of levels in '
#     671                              'MultiIndex.')
#     672
#
# ValueError: Length of names must match number of levels in MultiIndex.

# %% [markdown]
# ## Focusing only on a Part of Speech

# %%
tokens = vol.tokenlist(pages=False, pos=True, case=True).loc['body']
tokens.loc[(slice(None), ('NNP')),].sort_values('count', ascending=False)
# Out:
#                      count
# token          pos
# ,              ,      3249
# the            DT     1565
# .              .      1532
# and            CC     1249
# to             TO     1086
# "              ''      858
# of             IN      821
# "              ``      808
# she            PRP     700
# a              DT      671
# I              PRP     641
# was            VBD     632
# her            PRP$    529
# !              .       526
# in             IN      516
# June           NNP     492
# had            VBD     437
# it             PRP     437
# you            PRP     393
# he             PRP     370
# ;              :       355
# that           IN      346
# 's             POS     334
# for            IN      327
# with           IN      301
# at             IN      297
# said           VBD     252
# her            PRP     252
# ?              .       250
# n't            RB      237
# ...                    ...
# horseshoe      NN        1
# hillside       NN        1
# highschool     JJ        1
# heed           NN        1
# herbs          NNS       1
# heed           VB        1
# heel           NN        1
# Little         NNP       1
#                JJ        1
# LiT            NNP       1
# helper         NN        1
# helping        VBG       1
# helplessly     RB        1
# hen            NN        1
# hender         IN        1
# Letmeoutenhere .         1
# heresy         NN        1
# highest        JJS       1
# hers           JJ        1
# herse          JJ        1
# Law            NNP       1
# herself—the    PRP       1
# hesitancy      NN        1
# hesitate       VB        1
# hesitatingly   RB        1
# Latin          NNP       1
# hidden         VBN       1
# hide           VBP       1
# high-school    NN        1
# ••             NNP       1
#
# [5564 rows x 1 columns]

# %% [markdown]
# ## TODO: Comparative frequency
